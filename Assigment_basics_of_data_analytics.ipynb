# %% [markdown]
# 1.Define the role of a Data Analyst in your own words. What value do they bring to an organization?
# -> The process of examine raw data to discover patterns , draw insights and support decision making .
#   help organisation to make evidence based decisions.
#
# 2.  List three tools commonly used by Data Analysts and explain what each is mainly used for.
# ->  the three tools which use for data analytics are Power Bi  (Visuvalisation Tool) , Tableau-(Visuvalisation Tool),Excel-(Visuvalisation Tool and cleaning).
#
# 3. Write the end-to-end analytics workflow in the correct order and briefly explain each step.
#
# -> the work flow of data analytics works on 5 end to end steps
# 1.define the problem
# 2.data collection and understanding-use for the data
# 3.data prepration -cleaning and transformimg of thr data
# 4.data visuvalisation-analysed through charts and graphs
# 5.data analytics-decision making
#
# 4. What is Prompt Engineering, and explain any two types of prompts used in Generative AI?
# -> prompt engineering is the pratice of desigining, refining,abd optimization of tect or prompts given to Al for production of better inputs.
# 1.few shot prompting - it involves providing Al models withna few examples of inputs and outputs pairs to guide.
# 2.chain of thoughts- encourage AL model to explan resoining step by step.
#
# 5. What are the key differences between a Business Analyst and a Data Analyst in terms of roles,
# responsibilities, and focus?
# ->  roles,responsiblities and focus - data analyticsis to collect , clean , and analyse the database.whereas for busines analytics roles is to define business objective have a deep knowledgr of business domain, industry trends and use data to propose solutions.
#
# 6. Explain any three AI-powered ETL (Extract, Transform, Load) tools and how they are used in analytics.
# -> tools that are use for ETL are AWS Glue,IDMC,Matillion data productivity cloud.
#  they all are use in data analytics for data duplication, intelligent automation,AL powered code and query generation, data pipeline optimization etc.
#
# 7.  Give three applications of Data Analytics across different industries and explain how it creates value.
# ->  operation optimization
#     marketing campaigns
#     risk management
#     product development
#     finance , healthcare,retails, soprts, govermant
#
# 8. Explain the evolution of analytics, highlighting the different stages from Descriptive to Generative AI .
# -> there are total 4 stages of data analytics
#   1.Descriptive-what is the problem.
#   2.Diagnostic-why did it happened.
#   3.Predictive-what will happened.
#   4.Priscriptive-how can make it happened.
